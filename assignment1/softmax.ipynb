# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.320863
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -1.472571 analytic: -1.472571, relative error: 6.078930e-08
# numerical: -4.099637 analytic: -4.099637, relative error: 5.530608e-09
# numerical: -0.190681 analytic: -0.190681, relative error: 2.358230e-07
# numerical: 0.955447 analytic: 0.955447, relative error: 3.780711e-08
# numerical: 0.287247 analytic: 0.287247, relative error: 5.598513e-08
# numerical: -1.703075 analytic: -1.703076, relative error: 2.641491e-08
# numerical: 4.589794 analytic: 4.589794, relative error: 8.193479e-09
# numerical: 0.921713 analytic: 0.921713, relative error: 3.872294e-08
# numerical: 0.996014 analytic: 0.996014, relative error: 2.220275e-08
# numerical: -0.963039 analytic: -0.963039, relative error: 1.414754e-08
# numerical: -0.437746 analytic: -0.437746, relative error: 2.624385e-08
# numerical: 1.491344 analytic: 1.491344, relative error: 2.043617e-08
# numerical: 1.668642 analytic: 1.668642, relative error: 3.274198e-08
# numerical: 0.161448 analytic: 0.161448, relative error: 3.957243e-07
# numerical: -0.857355 analytic: -0.857355, relative error: 4.870333e-08
# numerical: 0.731445 analytic: 0.731445, relative error: 9.688949e-08
# numerical: -2.884535 analytic: -2.884535, relative error: 3.411671e-09
# numerical: -0.888555 analytic: -0.888555, relative error: 3.887244e-08
# numerical: -1.652392 analytic: -1.652393, relative error: 4.762434e-08
# numerical: 1.327989 analytic: 1.327989, relative error: 6.340867e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.320863e+00 computed in 0.070810s
# vectorized loss: 2.320863e+00 computed in 0.002996s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-8, 3e-8, 9e-8, 1.8e-7, 3.6e-7, 7.2e-7]
regularization_strengths = [1e3, 3e3, 9e3, 1.8e4, 3.6e4, 7.2e4, 1.44e5]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for learning_rate in learning_rates:
    for regularization_strength in regularization_strengths:
        print('learning_rate: %f, regularization_strength: %f' % (learning_rate, regularization_strength))
        softmax = Softmax()
        loss_hist = softmax.train(X_train, y_train, learning_rate, regularization_strength,
                      num_iters=1500, verbose=True)
        y_train_pred = softmax.predict(X_train)
        training_accuracy = np.mean(y_train == y_train_pred)
        y_val_pred = softmax.predict(X_val)
        validation_accuracy = np.mean(y_val == y_val_pred)
    
        results[(learning_rate, regularization_strength)] = \
            (training_accuracy, validation_accuracy)
            
        if(validation_accuracy > best_val):
            best_val = validation_accuracy
            best_softmax = softmax
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# learning_rate: 0.000000, regularization_strength: 1000.000000
# iteration 0 / 1500: loss 36.808458
# iteration 100 / 1500: loss 36.558121
# iteration 200 / 1500: loss 36.262824
# iteration 300 / 1500: loss 36.094191
# iteration 400 / 1500: loss 35.462718
# iteration 500 / 1500: loss 35.160344
# iteration 600 / 1500: loss 34.216423
# iteration 700 / 1500: loss 33.849932
# iteration 800 / 1500: loss 33.587743
# iteration 900 / 1500: loss 33.645321
# iteration 1000 / 1500: loss 33.652269
# iteration 1100 / 1500: loss 33.395484
# iteration 1200 / 1500: loss 33.208562
# iteration 1300 / 1500: loss 33.069427
# iteration 1400 / 1500: loss 33.133227
# learning_rate: 0.000000, regularization_strength: 3000.000000
# iteration 0 / 1500: loss 98.983757
# iteration 100 / 1500: loss 97.304905
# iteration 200 / 1500: loss 96.107744
# iteration 300 / 1500: loss 95.016356
# iteration 400 / 1500: loss 93.428587
# iteration 500 / 1500: loss 92.522436
# iteration 600 / 1500: loss 91.235807
# iteration 700 / 1500: loss 89.823157
# iteration 800 / 1500: loss 88.893416
# iteration 900 / 1500: loss 87.842899
# iteration 1000 / 1500: loss 86.485033
# iteration 1100 / 1500: loss 85.823441
# iteration 1200 / 1500: loss 84.259690
# iteration 1300 / 1500: loss 83.428040
# iteration 1400 / 1500: loss 82.452320
# learning_rate: 0.000000, regularization_strength: 9000.000000
# iteration 0 / 1500: loss 285.709398
# iteration 100 / 1500: loss 274.909506
# iteration 200 / 1500: loss 265.365828
# iteration 300 / 1500: loss 256.272686
# iteration 400 / 1500: loss 246.679169
# iteration 500 / 1500: loss 237.970219
# iteration 600 / 1500: loss 229.475660
# iteration 700 / 1500: loss 221.503311
# iteration 800 / 1500: loss 213.602240
# iteration 900 / 1500: loss 206.005474
# iteration 1000 / 1500: loss 198.559338
# iteration 1100 / 1500: loss 191.822603
# iteration 1200 / 1500: loss 185.188307
# iteration 1300 / 1500: loss 178.448603
# iteration 1400 / 1500: loss 172.249277
# learning_rate: 0.000000, regularization_strength: 18000.000000
# iteration 0 / 1500: loss 562.207789
# iteration 100 / 1500: loss 521.755788
# iteration 200 / 1500: loss 485.861200
# iteration 300 / 1500: loss 451.360771
# iteration 400 / 1500: loss 419.639202
# iteration 500 / 1500: loss 391.063708
# iteration 600 / 1500: loss 363.589290
# iteration 700 / 1500: loss 338.453550
# iteration 800 / 1500: loss 314.981359
# iteration 900 / 1500: loss 292.979842
# iteration 1000 / 1500: loss 272.877980
# iteration 1100 / 1500: loss 253.880797
# iteration 1200 / 1500: loss 236.177560
# iteration 1300 / 1500: loss 219.818128
# iteration 1400 / 1500: loss 204.761534
# learning_rate: 0.000000, regularization_strength: 36000.000000
# iteration 0 / 1500: loss 1110.849880
# iteration 100 / 1500: loss 961.277072
# iteration 200 / 1500: loss 832.356779
# iteration 300 / 1500: loss 720.945711
# iteration 400 / 1500: loss 624.128726
# iteration 500 / 1500: loss 540.746225
# iteration 600 / 1500: loss 467.975202
# iteration 700 / 1500: loss 405.484135
# iteration 800 / 1500: loss 351.285175
# iteration 900 / 1500: loss 304.331426
# iteration 1000 / 1500: loss 263.839261
# iteration 1100 / 1500: loss 228.627331
# iteration 1200 / 1500: loss 198.105220
# iteration 1300 / 1500: loss 171.731011
# iteration 1400 / 1500: loss 148.942273
# learning_rate: 0.000000, regularization_strength: 72000.000000
# iteration 0 / 1500: loss 2220.025389
# iteration 100 / 1500: loss 1664.329829
# iteration 200 / 1500: loss 1247.817247
# iteration 300 / 1500: loss 935.635004
# iteration 400 / 1500: loss 701.445814
# iteration 500 / 1500: loss 526.460377
# iteration 600 / 1500: loss 394.822947
# iteration 700 / 1500: loss 296.516582
# iteration 800 / 1500: loss 222.609979
# iteration 900 / 1500: loss 167.403002
# iteration 1000 / 1500: loss 126.075185
# iteration 1100 / 1500: loss 95.015091
# iteration 1200 / 1500: loss 71.721285
# iteration 1300 / 1500: loss 54.271827
# iteration 1400 / 1500: loss 41.270087
# learning_rate: 0.000000, regularization_strength: 144000.000000
# iteration 0 / 1500: loss 4433.615394
# iteration 100 / 1500: loss 2490.527917
# iteration 200 / 1500: loss 1399.377380
# iteration 300 / 1500: loss 786.467471
# iteration 400 / 1500: loss 442.524614
# iteration 500 / 1500: loss 249.511182
# iteration 600 / 1500: loss 141.122412
# iteration 700 / 1500: loss 80.162668
# iteration 800 / 1500: loss 45.941296
# iteration 900 / 1500: loss 26.787430
# iteration 1000 / 1500: loss 16.007029
# iteration 1100 / 1500: loss 9.990366
# iteration 1200 / 1500: loss 6.560451
# iteration 1300 / 1500: loss 4.624623
# iteration 1400 / 1500: loss 3.560786
# learning_rate: 0.000000, regularization_strength: 1000.000000
# iteration 0 / 1500: loss 35.264933
# iteration 100 / 1500: loss 34.460121
# iteration 200 / 1500: loss 33.655202
# iteration 300 / 1500: loss 32.745412
# iteration 400 / 1500: loss 32.489957
# iteration 500 / 1500: loss 32.094719
# iteration 600 / 1500: loss 31.775954
# iteration 700 / 1500: loss 30.739950
# iteration 800 / 1500: loss 30.490571
# iteration 900 / 1500: loss 30.318192
# iteration 1000 / 1500: loss 30.148624
# iteration 1100 / 1500: loss 29.514449
# iteration 1200 / 1500: loss 28.985676
# iteration 1300 / 1500: loss 28.793020
# iteration 1400 / 1500: loss 28.631654
# learning_rate: 0.000000, regularization_strength: 3000.000000
# iteration 0 / 1500: loss 99.652912
# iteration 100 / 1500: loss 96.103707
# iteration 200 / 1500: loss 91.631082
# iteration 300 / 1500: loss 88.119778
# iteration 400 / 1500: loss 84.938403
# iteration 500 / 1500: loss 81.874317
# iteration 600 / 1500: loss 78.916964
# iteration 700 / 1500: loss 76.059445
# iteration 800 / 1500: loss 73.599211
# iteration 900 / 1500: loss 70.595628
# iteration 1000 / 1500: loss 68.270648
# iteration 1100 / 1500: loss 65.869226
# iteration 1200 / 1500: loss 63.627800
# iteration 1300 / 1500: loss 61.135712
# iteration 1400 / 1500: loss 59.034268
# learning_rate: 0.000000, regularization_strength: 9000.000000
# iteration 0 / 1500: loss 279.683891
# iteration 100 / 1500: loss 250.214202
# iteration 200 / 1500: loss 224.692740
# iteration 300 / 1500: loss 201.368857
# iteration 400 / 1500: loss 180.618913
# iteration 500 / 1500: loss 162.120528
# iteration 600 / 1500: loss 145.875775
# iteration 700 / 1500: loss 130.900447
# iteration 800 / 1500: loss 117.565865
# iteration 900 / 1500: loss 105.580205
# iteration 1000 / 1500: loss 94.960202
# iteration 1100 / 1500: loss 85.417595
# iteration 1200 / 1500: loss 76.637126
# iteration 1300 / 1500: loss 68.998017
# iteration 1400 / 1500: loss 62.080489
# learning_rate: 0.000000, regularization_strength: 18000.000000
# iteration 0 / 1500: loss 556.112395
# iteration 100 / 1500: loss 447.935457
# iteration 200 / 1500: loss 360.655585
# iteration 300 / 1500: loss 290.699649
# iteration 400 / 1500: loss 234.220428
# iteration 500 / 1500: loss 188.813778
# iteration 600 / 1500: loss 152.488731
# iteration 700 / 1500: loss 123.153474
# iteration 800 / 1500: loss 99.516349
# iteration 900 / 1500: loss 80.461576
# iteration 1000 / 1500: loss 65.217043
# iteration 1100 / 1500: loss 52.830848
# iteration 1200 / 1500: loss 43.085144
# iteration 1300 / 1500: loss 34.988395
# iteration 1400 / 1500: loss 28.603617
# learning_rate: 0.000000, regularization_strength: 36000.000000
# iteration 0 / 1500: loss 1096.609731
# iteration 100 / 1500: loss 711.399749
# iteration 200 / 1500: loss 461.486028
# iteration 300 / 1500: loss 299.978947
# iteration 400 / 1500: loss 195.357411
# iteration 500 / 1500: loss 127.252749
# iteration 600 / 1500: loss 83.265571
# iteration 700 / 1500: loss 54.759449
# iteration 800 / 1500: loss 36.273512
# iteration 900 / 1500: loss 24.234000
# iteration 1000 / 1500: loss 16.511845
# iteration 1100 / 1500: loss 11.367155
# iteration 1200 / 1500: loss 8.183027
# iteration 1300 / 1500: loss 6.067459
# iteration 1400 / 1500: loss 4.640860
# learning_rate: 0.000000, regularization_strength: 72000.000000
# iteration 0 / 1500: loss 2216.632697
# iteration 100 / 1500: loss 933.191241
# iteration 200 / 1500: loss 393.094420
# iteration 300 / 1500: loss 166.557767
# iteration 400 / 1500: loss 71.217072
# iteration 500 / 1500: loss 31.114482
# iteration 600 / 1500: loss 14.348284
# iteration 700 / 1500: loss 7.285119
# iteration 800 / 1500: loss 4.310339
# iteration 900 / 1500: loss 3.067974
# iteration 1000 / 1500: loss 2.571104
# iteration 1100 / 1500: loss 2.320643
# iteration 1200 / 1500: loss 2.232208
# iteration 1300 / 1500: loss 2.180078
# iteration 1400 / 1500: loss 2.197929
# learning_rate: 0.000000, regularization_strength: 144000.000000
# iteration 0 / 1500: loss 4404.049727
# iteration 100 / 1500: loss 777.466371
# iteration 200 / 1500: loss 138.704562
# iteration 300 / 1500: loss 26.255411
# iteration 400 / 1500: loss 6.450223
# iteration 500 / 1500: loss 2.961426
# iteration 600 / 1500: loss 2.337367
# iteration 700 / 1500: loss 2.229289
# iteration 800 / 1500: loss 2.208187
# iteration 900 / 1500: loss 2.234354
# iteration 1000 / 1500: loss 2.218339
# iteration 1100 / 1500: loss 2.184282
# iteration 1200 / 1500: loss 2.209696
# iteration 1300 / 1500: loss 2.212527
# iteration 1400 / 1500: loss 2.213976
# learning_rate: 0.000000, regularization_strength: 1000.000000
# iteration 0 / 1500: loss 37.211208
# iteration 100 / 1500: loss 33.486117
# iteration 200 / 1500: loss 32.007459
# iteration 300 / 1500: loss 30.859726
# iteration 400 / 1500: loss 29.592112
# iteration 500 / 1500: loss 28.553113
# iteration 600 / 1500: loss 27.577896
# iteration 700 / 1500: loss 26.661546
# iteration 800 / 1500: loss 25.478161
# iteration 900 / 1500: loss 24.834441
# iteration 1000 / 1500: loss 23.730371
# iteration 1100 / 1500: loss 22.895605
# iteration 1200 / 1500: loss 22.368898
# iteration 1300 / 1500: loss 21.570845
# iteration 1400 / 1500: loss 20.728770
# learning_rate: 0.000000, regularization_strength: 3000.000000
# iteration 0 / 1500: loss 96.343880
# iteration 100 / 1500: loss 85.518268
# iteration 200 / 1500: loss 76.380513
# iteration 300 / 1500: loss 68.883850
# iteration 400 / 1500: loss 61.862526
# iteration 500 / 1500: loss 55.200391
# iteration 600 / 1500: loss 49.761226
# iteration 700 / 1500: loss 44.897153
# iteration 800 / 1500: loss 40.445452
# iteration 900 / 1500: loss 36.467177
# iteration 1000 / 1500: loss 32.721906
# iteration 1100 / 1500: loss 29.491593
# iteration 1200 / 1500: loss 26.621366
# iteration 1300 / 1500: loss 24.142406
# iteration 1400 / 1500: loss 21.741958
# learning_rate: 0.000000, regularization_strength: 9000.000000
# iteration 0 / 1500: loss 282.505807
# iteration 100 / 1500: loss 201.966538
# iteration 200 / 1500: loss 146.176628
# iteration 300 / 1500: loss 106.021334
# iteration 400 / 1500: loss 77.025848
# iteration 500 / 1500: loss 56.137703
# iteration 600 / 1500: loss 41.083781
# iteration 700 / 1500: loss 30.206364
# iteration 800 / 1500: loss 22.315807
# iteration 900 / 1500: loss 16.654978
# iteration 1000 / 1500: loss 12.556104
# iteration 1100 / 1500: loss 9.665425
# iteration 1200 / 1500: loss 7.628892
# iteration 1300 / 1500: loss 5.961911
# iteration 1400 / 1500: loss 4.822584
# learning_rate: 0.000000, regularization_strength: 18000.000000
# iteration 0 / 1500: loss 558.226201
# iteration 100 / 1500: loss 291.533050
# iteration 200 / 1500: loss 152.985226
# iteration 300 / 1500: loss 80.760699
# iteration 400 / 1500: loss 43.117702
# iteration 500 / 1500: loss 23.513939
# iteration 600 / 1500: loss 13.167522
# iteration 700 / 1500: loss 7.849979
# iteration 800 / 1500: loss 5.109876
# iteration 900 / 1500: loss 3.667114
# iteration 1000 / 1500: loss 2.870840
# iteration 1100 / 1500: loss 2.542882
# iteration 1200 / 1500: loss 2.252878
# iteration 1300 / 1500: loss 2.157829
# iteration 1400 / 1500: loss 2.144375
# learning_rate: 0.000000, regularization_strength: 36000.000000
# iteration 0 / 1500: loss 1105.869260
# iteration 100 / 1500: loss 301.590289
# iteration 200 / 1500: loss 83.524910
# iteration 300 / 1500: loss 24.280798
# iteration 400 / 1500: loss 8.152526
# iteration 500 / 1500: loss 3.753248
# iteration 600 / 1500: loss 2.588631
# iteration 700 / 1500: loss 2.246748
# iteration 800 / 1500: loss 2.179404
# iteration 900 / 1500: loss 2.131348
# iteration 1000 / 1500: loss 2.137306
# iteration 1100 / 1500: loss 2.153207
# iteration 1200 / 1500: loss 2.078299
# iteration 1300 / 1500: loss 2.149866
# iteration 1400 / 1500: loss 2.092430
# learning_rate: 0.000000, regularization_strength: 72000.000000
# iteration 0 / 1500: loss 2174.608771
# iteration 100 / 1500: loss 161.568825
# iteration 200 / 1500: loss 13.880829
# iteration 300 / 1500: loss 3.041668
# iteration 400 / 1500: loss 2.225541
# iteration 500 / 1500: loss 2.193311
# iteration 600 / 1500: loss 2.166154
# iteration 700 / 1500: loss 2.204725
# iteration 800 / 1500: loss 2.185455
# iteration 900 / 1500: loss 2.176564
# iteration 1000 / 1500: loss 2.191766
# iteration 1100 / 1500: loss 2.150485
# iteration 1200 / 1500: loss 2.149602
# iteration 1300 / 1500: loss 2.173958
# iteration 1400 / 1500: loss 2.146139
# learning_rate: 0.000000, regularization_strength: 144000.000000
# iteration 0 / 1500: loss 4403.919048
# iteration 100 / 1500: loss 25.185239
# iteration 200 / 1500: loss 2.330626
# iteration 300 / 1500: loss 2.200843
# iteration 400 / 1500: loss 2.207977
# iteration 500 / 1500: loss 2.222988
# iteration 600 / 1500: loss 2.211106
# iteration 700 / 1500: loss 2.176208
# iteration 800 / 1500: loss 2.222327
# iteration 900 / 1500: loss 2.234376
# iteration 1000 / 1500: loss 2.217246
# iteration 1100 / 1500: loss 2.197824
# iteration 1200 / 1500: loss 2.197461
# iteration 1300 / 1500: loss 2.244110
# iteration 1400 / 1500: loss 2.224168
# learning_rate: 0.000000, regularization_strength: 1000.000000
# iteration 0 / 1500: loss 36.543998
# iteration 100 / 1500: loss 32.674258
# iteration 200 / 1500: loss 29.855749
# iteration 300 / 1500: loss 27.926347
# iteration 400 / 1500: loss 25.903560
# iteration 500 / 1500: loss 24.418913
# iteration 600 / 1500: loss 22.378412
# iteration 700 / 1500: loss 20.721368
# iteration 800 / 1500: loss 19.524247
# iteration 900 / 1500: loss 18.153193
# iteration 1000 / 1500: loss 16.961330
# iteration 1100 / 1500: loss 15.896668
# iteration 1200 / 1500: loss 14.950346
# iteration 1300 / 1500: loss 13.975904
# iteration 1400 / 1500: loss 13.025302
# learning_rate: 0.000000, regularization_strength: 3000.000000
# iteration 0 / 1500: loss 97.962961
# iteration 100 / 1500: loss 77.457604
# iteration 200 / 1500: loss 62.294583
# iteration 300 / 1500: loss 50.253413
# iteration 400 / 1500: loss 40.770946
# iteration 500 / 1500: loss 33.023936
# iteration 600 / 1500: loss 27.077444
# iteration 700 / 1500: loss 22.056879
# iteration 800 / 1500: loss 18.126443
# iteration 900 / 1500: loss 14.952730
# iteration 1000 / 1500: loss 12.276215
# iteration 1100 / 1500: loss 10.302640
# iteration 1200 / 1500: loss 8.729679
# iteration 1300 / 1500: loss 7.419153
# iteration 1400 / 1500: loss 6.288316
# learning_rate: 0.000000, regularization_strength: 9000.000000
# iteration 0 / 1500: loss 281.118590
# iteration 100 / 1500: loss 146.434712
# iteration 200 / 1500: loss 77.062110
# iteration 300 / 1500: loss 41.097740
# iteration 400 / 1500: loss 22.339420
# iteration 500 / 1500: loss 12.685670
# iteration 600 / 1500: loss 7.550332
# iteration 700 / 1500: loss 4.837437
# iteration 800 / 1500: loss 3.489788
# iteration 900 / 1500: loss 2.825862
# iteration 1000 / 1500: loss 2.376106
# iteration 1100 / 1500: loss 2.151692
# iteration 1200 / 1500: loss 2.099230
# iteration 1300 / 1500: loss 2.027675
# iteration 1400 / 1500: loss 2.079845
# learning_rate: 0.000000, regularization_strength: 18000.000000
# iteration 0 / 1500: loss 556.797489
# iteration 100 / 1500: loss 152.307798
# iteration 200 / 1500: loss 42.785995
# iteration 300 / 1500: loss 13.107001
# iteration 400 / 1500: loss 5.061057
# iteration 500 / 1500: loss 2.912058
# iteration 600 / 1500: loss 2.304900
# iteration 700 / 1500: loss 2.161343
# iteration 800 / 1500: loss 2.062597
# iteration 900 / 1500: loss 2.045874
# iteration 1000 / 1500: loss 2.016809
# iteration 1100 / 1500: loss 2.064658
# iteration 1200 / 1500: loss 2.127130
# iteration 1300 / 1500: loss 2.008899
# iteration 1400 / 1500: loss 2.042074
# learning_rate: 0.000000, regularization_strength: 36000.000000
# iteration 0 / 1500: loss 1110.618507
# iteration 100 / 1500: loss 83.190354
# iteration 200 / 1500: loss 8.076909
# iteration 300 / 1500: loss 2.593398
# iteration 400 / 1500: loss 2.160896
# iteration 500 / 1500: loss 2.131848
# iteration 600 / 1500: loss 2.112088
# iteration 700 / 1500: loss 2.088064
# iteration 800 / 1500: loss 2.089179
# iteration 900 / 1500: loss 2.131379
# iteration 1000 / 1500: loss 2.111245
# iteration 1100 / 1500: loss 2.151320
# iteration 1200 / 1500: loss 2.056605
# iteration 1300 / 1500: loss 2.124089
# iteration 1400 / 1500: loss 2.128764
# learning_rate: 0.000000, regularization_strength: 72000.000000
# iteration 0 / 1500: loss 2219.925403
# iteration 100 / 1500: loss 13.759625
# iteration 200 / 1500: loss 2.260124
# iteration 300 / 1500: loss 2.151537
# iteration 400 / 1500: loss 2.198867
# iteration 500 / 1500: loss 2.205544
# iteration 600 / 1500: loss 2.147815
# iteration 700 / 1500: loss 2.162714
# iteration 800 / 1500: loss 2.185586
# iteration 900 / 1500: loss 2.195650
# iteration 1000 / 1500: loss 2.167414
# iteration 1100 / 1500: loss 2.192164
# iteration 1200 / 1500: loss 2.128199
# iteration 1300 / 1500: loss 2.194087
# iteration 1400 / 1500: loss 2.133829
# learning_rate: 0.000000, regularization_strength: 144000.000000
# iteration 0 / 1500: loss 4357.774046
# iteration 100 / 1500: loss 2.311005
# iteration 200 / 1500: loss 2.212049
# iteration 300 / 1500: loss 2.214859
# iteration 400 / 1500: loss 2.201813
# iteration 500 / 1500: loss 2.261574
# iteration 600 / 1500: loss 2.201216
# iteration 700 / 1500: loss 2.200585
# iteration 800 / 1500: loss 2.194875
# iteration 900 / 1500: loss 2.229106
# iteration 1000 / 1500: loss 2.191423
# iteration 1100 / 1500: loss 2.202787
# iteration 1200 / 1500: loss 2.235591
# iteration 1300 / 1500: loss 2.224940
# iteration 1400 / 1500: loss 2.231175
# learning_rate: 0.000000, regularization_strength: 1000.000000
# iteration 0 / 1500: loss 36.681973
# iteration 100 / 1500: loss 29.445341
# iteration 200 / 1500: loss 25.490326
# iteration 300 / 1500: loss 22.269662
# iteration 400 / 1500: loss 19.181623
# iteration 500 / 1500: loss 16.938204
# iteration 600 / 1500: loss 14.929349
# iteration 700 / 1500: loss 12.866626
# iteration 800 / 1500: loss 11.358480
# iteration 900 / 1500: loss 10.040736
# iteration 1000 / 1500: loss 8.916482
# iteration 1100 / 1500: loss 7.963267
# iteration 1200 / 1500: loss 7.174793
# iteration 1300 / 1500: loss 6.518735
# iteration 1400 / 1500: loss 5.712419
# learning_rate: 0.000000, regularization_strength: 3000.000000
# iteration 0 / 1500: loss 96.559792
# iteration 100 / 1500: loss 61.817539
# iteration 200 / 1500: loss 40.469347
# iteration 300 / 1500: loss 26.741643
# iteration 400 / 1500: loss 17.928969
# iteration 500 / 1500: loss 12.100534
# iteration 600 / 1500: loss 8.573987
# iteration 700 / 1500: loss 6.282812
# iteration 800 / 1500: loss 4.640018
# iteration 900 / 1500: loss 3.737835
# iteration 1000 / 1500: loss 3.049323
# iteration 1100 / 1500: loss 2.627298
# iteration 1200 / 1500: loss 2.492222
# iteration 1300 / 1500: loss 2.332860
# iteration 1400 / 1500: loss 2.123830
# learning_rate: 0.000000, regularization_strength: 9000.000000
# iteration 0 / 1500: loss 277.833065
# iteration 100 / 1500: loss 75.846490
# iteration 200 / 1500: loss 21.971520
# iteration 300 / 1500: loss 7.390783
# iteration 400 / 1500: loss 3.377717
# iteration 500 / 1500: loss 2.441951
# iteration 600 / 1500: loss 2.118362
# iteration 700 / 1500: loss 1.913352
# iteration 800 / 1500: loss 1.980817
# iteration 900 / 1500: loss 1.957984
# iteration 1000 / 1500: loss 2.032697
# iteration 1100 / 1500: loss 1.939644
# iteration 1200 / 1500: loss 1.958658
# iteration 1300 / 1500: loss 1.975548
# iteration 1400 / 1500: loss 1.976985
# learning_rate: 0.000000, regularization_strength: 18000.000000
# iteration 0 / 1500: loss 553.239392
# iteration 100 / 1500: loss 42.200483
# iteration 200 / 1500: loss 5.010191
# iteration 300 / 1500: loss 2.246439
# iteration 400 / 1500: loss 2.065013
# iteration 500 / 1500: loss 2.059641
# iteration 600 / 1500: loss 2.061955
# iteration 700 / 1500: loss 2.075396
# iteration 800 / 1500: loss 2.037241
# iteration 900 / 1500: loss 2.079159
# iteration 1000 / 1500: loss 2.060342
# iteration 1100 / 1500: loss 2.090448
# iteration 1200 / 1500: loss 2.019230
# iteration 1300 / 1500: loss 2.062651
# iteration 1400 / 1500: loss 2.031163
# learning_rate: 0.000000, regularization_strength: 36000.000000
# iteration 0 / 1500: loss 1101.771546
# iteration 100 / 1500: loss 7.761645
# iteration 200 / 1500: loss 2.192172
# iteration 300 / 1500: loss 2.076401
# iteration 400 / 1500: loss 2.089247
# iteration 500 / 1500: loss 2.097360
# iteration 600 / 1500: loss 2.085256
# iteration 700 / 1500: loss 2.032950
# iteration 800 / 1500: loss 2.143995
# iteration 900 / 1500: loss 2.072215
# iteration 1000 / 1500: loss 2.136861
# iteration 1100 / 1500: loss 2.120061
# iteration 1200 / 1500: loss 2.078093
# iteration 1300 / 1500: loss 2.163601
# iteration 1400 / 1500: loss 2.100672
# learning_rate: 0.000000, regularization_strength: 72000.000000
# iteration 0 / 1500: loss 2221.883575
# iteration 100 / 1500: loss 2.252987
# iteration 200 / 1500: loss 2.202625
# iteration 300 / 1500: loss 2.150660
# iteration 400 / 1500: loss 2.210812
# iteration 500 / 1500: loss 2.150832
# iteration 600 / 1500: loss 2.165393
# iteration 700 / 1500: loss 2.182907
# iteration 800 / 1500: loss 2.148365
# iteration 900 / 1500: loss 2.187401
# iteration 1000 / 1500: loss 2.171824
# iteration 1100 / 1500: loss 2.184997
# iteration 1200 / 1500: loss 2.188289
# iteration 1300 / 1500: loss 2.143954
# iteration 1400 / 1500: loss 2.149142
# learning_rate: 0.000000, regularization_strength: 144000.000000
# iteration 0 / 1500: loss 4440.267219
# iteration 100 / 1500: loss 2.248853
# iteration 200 / 1500: loss 2.221610
# iteration 300 / 1500: loss 2.223059
# iteration 400 / 1500: loss 2.215644
# iteration 500 / 1500: loss 2.246962
# iteration 600 / 1500: loss 2.223610
# iteration 700 / 1500: loss 2.185664
# iteration 800 / 1500: loss 2.249226
# iteration 900 / 1500: loss 2.224217
# iteration 1000 / 1500: loss 2.252801
# iteration 1100 / 1500: loss 2.215873
# iteration 1200 / 1500: loss 2.207392
# iteration 1300 / 1500: loss 2.223756
# iteration 1400 / 1500: loss 2.227933
# learning_rate: 0.000001, regularization_strength: 1000.000000
# iteration 0 / 1500: loss 36.985687
# iteration 100 / 1500: loss 25.819090
# iteration 200 / 1500: loss 19.756233
# iteration 300 / 1500: loss 14.925872
# iteration 400 / 1500: loss 11.587058
# iteration 500 / 1500: loss 9.141887
# iteration 600 / 1500: loss 7.193763
# iteration 700 / 1500: loss 5.812106
# iteration 800 / 1500: loss 4.799855
# iteration 900 / 1500: loss 3.924742
# iteration 1000 / 1500: loss 3.426766
# iteration 1100 / 1500: loss 3.024201
# iteration 1200 / 1500: loss 2.699255
# iteration 1300 / 1500: loss 2.597393
# iteration 1400 / 1500: loss 2.329145
# learning_rate: 0.000001, regularization_strength: 3000.000000
# iteration 0 / 1500: loss 97.142523
# iteration 100 / 1500: loss 40.346520
# iteration 200 / 1500: loss 17.818043
# iteration 300 / 1500: loss 8.526163
# iteration 400 / 1500: loss 4.694715
# iteration 500 / 1500: loss 2.964181
# iteration 600 / 1500: loss 2.403118
# iteration 700 / 1500: loss 2.130578
# iteration 800 / 1500: loss 1.941921
# iteration 900 / 1500: loss 2.018212
# iteration 1000 / 1500: loss 1.932737
# iteration 1100 / 1500: loss 1.986132
# iteration 1200 / 1500: loss 1.946251
# iteration 1300 / 1500: loss 1.882978
# iteration 1400 / 1500: loss 1.946724
# learning_rate: 0.000001, regularization_strength: 9000.000000
# iteration 0 / 1500: loss 282.707598
# iteration 100 / 1500: loss 22.312875
# iteration 200 / 1500: loss 3.457020
# iteration 300 / 1500: loss 2.099291
# iteration 400 / 1500: loss 1.985684
# iteration 500 / 1500: loss 2.009503
# iteration 600 / 1500: loss 2.029277
# iteration 700 / 1500: loss 1.960059
# iteration 800 / 1500: loss 2.115589
# iteration 900 / 1500: loss 2.090238
# iteration 1000 / 1500: loss 2.003139
# iteration 1100 / 1500: loss 2.042076
# iteration 1200 / 1500: loss 2.008079
# iteration 1300 / 1500: loss 1.999386
# iteration 1400 / 1500: loss 2.018502
# learning_rate: 0.000001, regularization_strength: 18000.000000
# iteration 0 / 1500: loss 561.162735
# iteration 100 / 1500: loss 4.915929
# iteration 200 / 1500: loss 2.089797
# iteration 300 / 1500: loss 2.085597
# iteration 400 / 1500: loss 2.035239
# iteration 500 / 1500: loss 2.020506
# iteration 600 / 1500: loss 2.102560
# iteration 700 / 1500: loss 2.109289
# iteration 800 / 1500: loss 2.107051
# iteration 900 / 1500: loss 2.077319
# iteration 1000 / 1500: loss 2.087542
# iteration 1100 / 1500: loss 2.093417
# iteration 1200 / 1500: loss 2.056622
# iteration 1300 / 1500: loss 2.033184
# iteration 1400 / 1500: loss 2.021515
# learning_rate: 0.000001, regularization_strength: 36000.000000
# iteration 0 / 1500: loss 1108.877044
# iteration 100 / 1500: loss 2.166981
# iteration 200 / 1500: loss 2.196701
# iteration 300 / 1500: loss 2.128828
# iteration 400 / 1500: loss 2.083402
# iteration 500 / 1500: loss 2.171364
# iteration 600 / 1500: loss 2.122540
# iteration 700 / 1500: loss 2.117483
# iteration 800 / 1500: loss 2.097429
# iteration 900 / 1500: loss 2.162382
# iteration 1000 / 1500: loss 2.085396
# iteration 1100 / 1500: loss 2.173135
# iteration 1200 / 1500: loss 2.149415
# iteration 1300 / 1500: loss 2.187251
# iteration 1400 / 1500: loss 2.081290
# learning_rate: 0.000001, regularization_strength: 72000.000000
# iteration 0 / 1500: loss 2225.590383
# iteration 100 / 1500: loss 2.162291
# iteration 200 / 1500: loss 2.171131
# iteration 300 / 1500: loss 2.212629
# iteration 400 / 1500: loss 2.192470
# iteration 500 / 1500: loss 2.139837
# iteration 600 / 1500: loss 2.192817
# iteration 700 / 1500: loss 2.176141
# iteration 800 / 1500: loss 2.206736
# iteration 900 / 1500: loss 2.203636
# iteration 1000 / 1500: loss 2.187799
# iteration 1100 / 1500: loss 2.184993
# iteration 1200 / 1500: loss 2.154620
# iteration 1300 / 1500: loss 2.135393
# iteration 1400 / 1500: loss 2.173776
# learning_rate: 0.000001, regularization_strength: 144000.000000
# iteration 0 / 1500: loss 4439.661220
# iteration 100 / 1500: loss 2.233706
# iteration 200 / 1500: loss 2.210360
# iteration 300 / 1500: loss 2.203556
# iteration 400 / 1500: loss 2.223103
# iteration 500 / 1500: loss 2.217962
# iteration 600 / 1500: loss 2.176121
# iteration 700 / 1500: loss 2.234371
# iteration 800 / 1500: loss 2.201973
# iteration 900 / 1500: loss 2.220463
# iteration 1000 / 1500: loss 2.211821
# iteration 1100 / 1500: loss 2.238185
# iteration 1200 / 1500: loss 2.206620
# iteration 1300 / 1500: loss 2.228460
# iteration 1400 / 1500: loss 2.224011
# lr 1.000000e-08 reg 1.000000e+03 train accuracy: 0.155918 val accuracy: 0.169000
# lr 1.000000e-08 reg 3.000000e+03 train accuracy: 0.150163 val accuracy: 0.140000
# lr 1.000000e-08 reg 9.000000e+03 train accuracy: 0.160163 val accuracy: 0.171000
# lr 1.000000e-08 reg 1.800000e+04 train accuracy: 0.167429 val accuracy: 0.144000
# lr 1.000000e-08 reg 3.600000e+04 train accuracy: 0.210776 val accuracy: 0.213000
# lr 1.000000e-08 reg 7.200000e+04 train accuracy: 0.243898 val accuracy: 0.237000
# lr 1.000000e-08 reg 1.440000e+05 train accuracy: 0.274061 val accuracy: 0.285000
# lr 3.000000e-08 reg 1.000000e+03 train accuracy: 0.209429 val accuracy: 0.210000
# lr 3.000000e-08 reg 3.000000e+03 train accuracy: 0.204531 val accuracy: 0.198000
# lr 3.000000e-08 reg 9.000000e+03 train accuracy: 0.227041 val accuracy: 0.220000
# lr 3.000000e-08 reg 1.800000e+04 train accuracy: 0.276714 val accuracy: 0.275000
# lr 3.000000e-08 reg 3.600000e+04 train accuracy: 0.308000 val accuracy: 0.327000
# lr 3.000000e-08 reg 7.200000e+04 train accuracy: 0.297510 val accuracy: 0.316000
# lr 3.000000e-08 reg 1.440000e+05 train accuracy: 0.277755 val accuracy: 0.286000
# lr 9.000000e-08 reg 1.000000e+03 train accuracy: 0.252531 val accuracy: 0.263000
# lr 9.000000e-08 reg 3.000000e+03 train accuracy: 0.287531 val accuracy: 0.288000
# lr 9.000000e-08 reg 9.000000e+03 train accuracy: 0.349286 val accuracy: 0.363000
# lr 9.000000e-08 reg 1.800000e+04 train accuracy: 0.339939 val accuracy: 0.353000
# lr 9.000000e-08 reg 3.600000e+04 train accuracy: 0.319143 val accuracy: 0.336000
# lr 9.000000e-08 reg 7.200000e+04 train accuracy: 0.296918 val accuracy: 0.308000
# lr 9.000000e-08 reg 1.440000e+05 train accuracy: 0.286122 val accuracy: 0.302000
# lr 1.800000e-07 reg 1.000000e+03 train accuracy: 0.301327 val accuracy: 0.297000
# lr 1.800000e-07 reg 3.000000e+03 train accuracy: 0.360735 val accuracy: 0.368000
# lr 1.800000e-07 reg 9.000000e+03 train accuracy: 0.359327 val accuracy: 0.378000
# lr 1.800000e-07 reg 1.800000e+04 train accuracy: 0.338551 val accuracy: 0.355000
# lr 1.800000e-07 reg 3.600000e+04 train accuracy: 0.319510 val accuracy: 0.332000
# lr 1.800000e-07 reg 7.200000e+04 train accuracy: 0.304388 val accuracy: 0.313000
# lr 1.800000e-07 reg 1.440000e+05 train accuracy: 0.285694 val accuracy: 0.294000
# lr 3.600000e-07 reg 1.000000e+03 train accuracy: 0.367388 val accuracy: 0.369000
# lr 3.600000e-07 reg 3.000000e+03 train accuracy: 0.381796 val accuracy: 0.391000
# lr 3.600000e-07 reg 9.000000e+03 train accuracy: 0.363122 val accuracy: 0.374000
# lr 3.600000e-07 reg 1.800000e+04 train accuracy: 0.332735 val accuracy: 0.345000
# lr 3.600000e-07 reg 3.600000e+04 train accuracy: 0.323286 val accuracy: 0.340000
# lr 3.600000e-07 reg 7.200000e+04 train accuracy: 0.301327 val accuracy: 0.321000
# lr 3.600000e-07 reg 1.440000e+05 train accuracy: 0.267571 val accuracy: 0.281000
# lr 7.200000e-07 reg 1.000000e+03 train accuracy: 0.399367 val accuracy: 0.405000
# lr 7.200000e-07 reg 3.000000e+03 train accuracy: 0.384388 val accuracy: 0.388000
# lr 7.200000e-07 reg 9.000000e+03 train accuracy: 0.359306 val accuracy: 0.372000
# lr 7.200000e-07 reg 1.800000e+04 train accuracy: 0.330816 val accuracy: 0.347000
# lr 7.200000e-07 reg 3.600000e+04 train accuracy: 0.312122 val accuracy: 0.332000
# lr 7.200000e-07 reg 7.200000e+04 train accuracy: 0.289082 val accuracy: 0.310000
# lr 7.200000e-07 reg 1.440000e+05 train accuracy: 0.272449 val accuracy: 0.289000
# best validation accuracy achieved during cross-validation: 0.405000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.384000

# %% [markdown]
# **Inline Question** - *True or False*
#
# It's possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# *Your answer*:
#
# *Your explanation*:

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
